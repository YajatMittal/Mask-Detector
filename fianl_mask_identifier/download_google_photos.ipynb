# %%
from selenium import webdriver
import time
import urllib.request
import os
from selenium.webdriver.common.keys import Keys
import os
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
browser = webdriver.Chrome("chromedriver") #incase you are chrome
browser.get("https://www.google.com/")
search = browser.find_element_by_name('q')
key_words = "person with mask"
search.send_keys(key_words,Keys.ENTER)
elem = browser.find_element_by_link_text('Images')
elem.get_attribute('href')
elem.click()
value = 0
for i in range(20):
    browser.execute_script('scrollBy('+ str(value) +',+1000);')
    value += 1000
    time.sleep(3)
elem1 = browser.find_element_by_id('islmp')
sub = elem1.find_elements_by_tag_name('img')
try:
    os.mkdir('downloads')
except FileExistsError:
    pass

count = 0
for i in sub:
    src = i.get_attribute('src')
    try:
        if src != None:
            src  = str(src)
            print(src)
            count+=1
            urllib.request.urlretrieve(src, os.path.join('downloads','image'+str(count)+'.jpg'))
        else:
            raise TypeError
    except TypeError:
        print('fail')
# Out:
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# data:image/jpeg;base64,...
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRpARiFG1U1nSI3B60CbO5ZER8Jm59oGcNuIA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKeRr6UJRaemRey1CndFuP_MXocK5E2ELkfA&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSivkHsemulnrYa_9V8R49mE43vx5xUoqd3IQ&usqp=CAU
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKc39au7WNS5cizXYTPH8mpzUl5GoYa1gj7Q&usqp=CAU
# ...

# %%
for img in os.listdir("downloads"):
    file = os.path.join('downloads',img)
    new_name = "3" + img 
    file_new = os.path.join('downloads',new_name)
    os.rename(file,file_new)
